# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

# %%
movies_data = pd.read_csv("movies_metadata.csv")
small_links = pd.read_csv("small_links.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
movies_data = movies_data.drop([19730, 29503, 35587])

# %%
movies_data['id'] = movies_data['id'].astype('int')
smd = movies_data
smd.shape
# Out:
# (45463, 24)

# %%
smd['tagline'] = smd['tagline'].fillna('')
smd['description'] = smd['overview'] + smd['tagline']
smd['description'] = smd['description'].fillna('')

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(smd['description'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
smd = smd.reset_index()
titles = smd['title']
indices = pd.Series(smd.index, index=smd['title'])

# %%
def get_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
get_recommendations("The Champ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mr/3szmdm1d3sj80jkk3tl1c_t40000gp/T/ipykernel_4627/1158402322.py in <module>
# ----> 1 get_recommendations("The Champ")
#
# /var/folders/mr/3szmdm1d3sj80jkk3tl1c_t40000gp/T/ipykernel_4627/3230424938.py in get_recommendations(title)
#       2     idx = indices[title]
#       3     sim_scores = list(enumerate(cosine_sim[idx]))
# ----> 4     sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
#       5     sim_scores = sim_scores[1:31]
#       6     movie_indices = [i[0] for i in sim_scores]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
simTwo = sorted(list(enumerate(cosine_sim[6793])), key=lambda x: x[1], reverse=True)

# %%
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
small_links["imdb_id"] = small_links["imdb_id"].astype("int")
movies_data["imdb_id"] = movies_data["imdb_id"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mr/3szmdm1d3sj80jkk3tl1c_t40000gp/T/ipykernel_5777/1328135453.py in <module>
#       1 small_links["imdb_id"] = small_links["imdb_id"].astype("int")
# ----> 2 movies_data["imdb_id"] = movies_data["imdb_id"].astype("int")
#       3
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412
# ...

# %%
movies_data['imdb_id'].str.replace("tt","")
# Out:
# 0        0114709
# 1        0113497
# 2        0113228
# 3        0114885
# 4        0113041
#           ...
# 45461    6209470
# 45462    2028550
# 45463    0303758
# 45464    0008536
# 45465    6980792
# Name: imdb_id, Length: 45466, dtype: object

# %%
small_links['imdb_id']
# Out:
# 0        114709
# 1        113497
# 2        113228
# 3        114885
# 4        113041
#          ...
# 9120    3859980
# 9121    4262980
# 9122    2531318
# 9123      27660
# 9124    3447228
# Name: imdb_id, Length: 9125, dtype: int64

# %%
num = input("Hello World")

# %%
num
# Out:
# 'hamzah'

# %%
input("Name: ")
