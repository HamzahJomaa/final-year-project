# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from surprise import Reader, Dataset, SVD
import mongodb as md

import warnings; warnings.simplefilter('ignore')

# %%
movies = md.read_mongo("finalyearproject","movies",True)
ratings = md.read_mongo("finalyearproject","reviews",True)
users = md.read_mongo("finalyearproject","users",True)
movies = movies.rename(columns={"_id":"on"})
movie_ratings = pd.merge(movies,ratings,on="on")
movies['year'] = pd.to_datetime(movies['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
movies_ratings = movie_ratings.rename(columns={"title_x":"movieTitle","title_y":"rateTitle"})
movies
# Out:
#                             on    tmdb                          title  \
# 0     624d882287b246f81c48c8b1     278       The Shawshank Redemption
# 1     624d882287b246f81c48c8b3   19404    Dilwale Dulhania Le Jayenge
# 2     624d882287b246f81c48c8b5     238                  The Godfather
# 3     624d882287b246f81c48c8b7  652837  Josee, the Tiger and the Fish
# 4     624d882287b246f81c48c8cf  533514   Violet Evergarden: The Movie
# ...                        ...     ...                            ...
# 1464  624d88d361dd768818c97646   16996                       17 Again
# 1465  624d88d361dd768818c9763a  141052                 Justice League
# 1466  624d88d361dd768818c9763e  102899                        Ant-Man
# 1467  624d88d361dd768818c97644   44912                  Green Lantern
# 1468  624d88d361dd768818c9763c  433945                    Tokyo Ghoul
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     With dreams of diving abroad, Tsuneo gets a jo...
# 4     As the world moves on from the war and technol...
# ...                                                 ...
# 1464  On the brink of a midlife crisis, 30-something...
# 1465  Fuelled by his restored faith in humanity and ...
# 1466  Armed with the astonishing ability to shrink i...
# 1467  For centuries, a small but powerful force of w...
# 1468  A Tokyo college student is attacked by a ghoul...
#
#                                               genres           genres_ids  \
# 0                                     [Crime, Drama]             [80, 18]
# 1                           [Comedy, Drama, Romance]      [35, 18, 10749]
# 2                                     [Crime, Drama]             [80, 18]
# 3                        [Animation, Drama, Romance]      [16, 18, 10749]
# 4               [Animation, Fantasy, Drama, Romance]  [16, 14, 18, 10749]
# ...                                              ...                  ...
# 1464                                        [Comedy]                 [35]
# 1465   [Action, Adventure, Fantasy, Science Fiction]    [28, 12, 14, 878]
# 1466            [Action, Adventure, Science Fiction]        [28, 12, 878]
# 1467  [Action, Adventure, Thriller, Science Fiction]    [28, 12, 53, 878]
# 1468               [Action, Horror, Drama, Thriller]     [28, 27, 18, 53]
#
#       vote_count  vote_average  popularity release_date  year
# 0              0      0.000000      78.147   1994-09-23  1994
# 1              0      0.000000      29.896   1995-10-20  1995
# 2              0      0.000000      91.215   1972-03-14  1972
# 3              1      3.000000      30.509   2020-12-25  2020
# 4              2      4.500000      42.120   2020-09-18  2020
# ...          ...           ...         ...          ...   ...
# 1464           0      0.000000      91.448   2009-03-11  2009
# 1465           3      3.666667      80.543   2017-11-15  2017
# 1466           0      0.000000      86.827   2015-07-14  2015
# 1467           1      2.000000      86.645   2011-06-16  2011
# 1468           0      0.000000      82.517   2017-07-16  2017
#
# [1469 rows x 11 columns]

# %%
vote_counts = movies[movies['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = movies[movies['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()

m = vote_counts.quantile(0.95)


qualified = movies[(movies['vote_count'] >= m) & (movies['vote_count'].notnull()) & (movies['vote_average'].notnull())][['tmdb','title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')

def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

qualified['wr'] = qualified.apply(weighted_rating, axis=1)
qualified = qualified.sort_values('wr', ascending=False)
qualified
# Out:
#        tmdb                                   title  year  vote_count  \
# 544   94810           Adventure Time: Distant Lands  2020          23
# 877   61602                            Cumbia Ninja  2013          10
# 118  154490     From the Second Side with Guy Zohar  2019          98
# 423   61175                         Steven Universe  2013          32
# 558   38693           Ninjago: Masters of Spinjitzu  2012          25
# 874   39518               My Babysitter's a Vampire  2011          23
# 868   33880                     The Legend of Korra  2012          22
# 786   65931                        Bungo Stray Dogs  2016          21
# 308   61852                            Henry Danger  2014          20
# 781   74440                            Harley Quinn  2019          19
# 482   68267          Trollhunters: Tales of Arcadia  2016          19
# 202   37606            The Amazing World of Gumball  2011          16
# 677   80040              Desafío Champions Sendokai  2013          16
# 454   99071                          Redo of Healer  2021          15
# 776   61617                    Over the Garden Wall  2014          15
# 991   78173               Dragons: Race to the Edge  2015          15
# 739   42509                             Steins;Gate  2011          14
# 676   91425                          Infinity Train  2019          14
# 88    67335                Sin senos sí hay paraíso  2016          14
# 141   75219                                   9-1-1  2018          13
# 193   71789                               SEAL Team  2017          13
# 705   97860                            Tower of God  2020          12
# 975   96203                                Gleipnir  2020          12
# 952   87491                     DC Super Hero Girls  2019          12
# 920   33623  The Avengers: Earth's Mightiest Heroes  2010          12
# 445  115304                      Disney Intertwined  2021          10
# 609   80564                             Banana Fish  2018           9
# 393  103409                       World's End Harem  2021           9
# 113  123876                  Komi Can't Communicate  2021           7
# 473   45140                         Teen Titans Go!  2013           7
# 938   94280                  Steven Universe Future  2019           7
# 349   74682                        I Am Not a Robot  2017           7
# 32    71790                                S.W.A.T.  2017          18
# 95    80623                                    BAKI  2018          16
# 50   108978                                 Reacher  2022          15
# 226   77184                 Halo: The Fall of Reach  2015          15
# 624   32118                           Generator Rex  2010          14
# 253   61889                      Marvel's Daredevil  2015          14
# 965   73946                   Inuyashiki: Last Hero  2017          13
# 150    1412                                   Arrow  2012          13
# 146  105009                         Tokyo Revengers  2021          13
# 368  110356                                 My Name  2021          13
# 270   80748                                     FBI  2018          13
# 161  120089                            SPY x FAMILY  2022          11
# 222   32798                           Hawaii Five-0  2010          10
# 498   67116                           Lethal Weapon  2016          10
# 166   89393                        9-1-1: Lone Star  2020          10
# 407   62710                               Blindspot  2015          10
# 830   32716                              Kickin' It  2011           9
# 606  123566                            Metal Family  2018           9
# 140   60797                                Scorpion  2014           8
# 435   67178                   Marvel's The Punisher  2017           8
# 848   96713                     The Midnight Gospel  2020           7
# 74   116479                                Anupamaa  2020           7
# 71   128794                            La Desalmada  2021           7
# 527   66579                  The Three Sides of Ana  2016           7
# 330   44914                              The Return  2013           7
# 485  135193              Malverde: The Patron Saint  2021          10
#
#      vote_average  popularity  \
# 544             4      94.913
# 877             4      84.417
# 118             3     308.512
# 423             3     114.513
# 558             3      92.998
# 874             3      26.212
# 868             3      74.010
# 786             3      56.469
# 308             3     151.604
# 781             3      53.952
# 482             3     104.666
# 202             3     204.655
# 677             3      13.193
# 454             3     107.355
# 776             3      44.819
# 991             3      62.374
# 739             3      34.946
# 676             3      34.164
# 88              3     363.884
# 141             3     253.901
# 193             3     210.145
# 705             3      39.368
# 975             3      25.693
# 952             3      20.998
# 920             3      41.647
# 445             3     110.056
# 609             3      55.489
# 393             3     122.050
# 113             3     315.658
# 473             3     101.089
# 938             3      60.998
# 349             3     133.341
# 32              2     831.289
# 95              2     347.778
# 50              2     537.137
# 226             2     192.103
# 624             2      38.942
# 253             2     174.029
# 965             2       7.533
# 150             2     247.846
# 146             2     249.271
# 368             2     127.085
# 270             2     172.574
# 161             2     236.666
# 222             2     192.769
# 498             2     103.200
# 166             2     232.430
# 407             2     118.226
# 830             2      34.339
# 606             2      62.279
# 140             2     253.218
# 435             2     112.172
# 848             2      37.714
# 74              2     442.771
# 71              2     443.194
# 527             1      96.987
# 330             1     143.141
# 485             1     103.894
#
#                                                 genres        wr
# 544      [Animation, Comedy, Family, Sci-Fi & Fantasy]  3.396092
# 877           [Crime, Drama, Comedy, Sci-Fi & Fantasy]  2.934280
# 118                             [News, War & Politics]  2.894122
# 423  [Action & Adventure, Animation, Comedy, Family...  2.714943
# 558  [Action & Adventure, Animation, Comedy, Kids, ...  2.652586
# 874  [Action & Adventure, Comedy, Kids, Family, Sci...  2.629425
# 868  [Action & Adventure, Animation, Drama, Family,...  2.616647
# 786  [Action & Adventure, Animation, Crime, Drama, ...  2.602956
# 308  [Action & Adventure, Drama, Comedy, Family, Sc...  2.588250
# 781  [Action & Adventure, Animation, Crime, Comedy,...  2.572414
# 482  [Action & Adventure, Animation, Comedy, Family...  2.572414
# 202      [Animation, Comedy, Family, Sci-Fi & Fantasy]  2.516642
# 677    [Action & Adventure, Animation, Comedy, Family]  2.516642
# 454  [Action & Adventure, Animation, Crime, Drama, ...  2.494671
# 776  [Animation, Comedy, Family, Sci-Fi & Fantasy, ...  2.494671
# 991  [Action & Adventure, Animation, Kids, Family, ...  2.494671
# 739  [Action & Adventure, Animation, Drama, Comedy,...  2.470608
# 676  [Action & Adventure, Animation, Kids, Family, ...  2.470608
# 88         [Action & Adventure, Crime, Drama, Mystery]  2.470608
# 141                 [Action & Adventure, Crime, Drama]  2.444138
# 193        [Action & Adventure, Drama, War & Politics]  2.444138
# 705  [Action & Adventure, Animation, Drama, Sci-Fi ...  2.414882
# 975  [Action & Adventure, Animation, Comedy, Sci-Fi...  2.414882
# 952        [Animation, Kids, Family, Sci-Fi & Fantasy]  2.414882
# 920  [Action & Adventure, Animation, Family, Sci-Fi...  2.414882
# 445          [Drama, Comedy, Family, Sci-Fi & Fantasy]  2.346045
# 609    [Action & Adventure, Animation, Drama, Mystery]  2.305172
# 393  [Action & Adventure, Animation, Drama, Sci-Fi ...  2.305172
# 113                         [Animation, Drama, Comedy]  2.205911
# 473      [Action & Adventure, Animation, Comedy, Kids]  2.205911
# 938  [Action & Adventure, Animation, Drama, Comedy,...  2.205911
# 349          [Drama, Comedy, Family, Sci-Fi & Fantasy]  2.205911
# 32                  [Action & Adventure, Crime, Drama]  1.835310
# 95       [Action & Adventure, Animation, Crime, Drama]  1.820990
# 50         [Action & Adventure, Crime, Drama, Mystery]  1.812853
# 226  [Action & Adventure, Animation, Family, Sci-Fi...  1.812853
# 624  [Action & Adventure, Animation, Kids, Family, ...  1.803941
# 253                 [Action & Adventure, Crime, Drama]  1.803941
# 965  [Action & Adventure, Animation, Crime, Drama, ...  1.794138
# 150        [Action & Adventure, Crime, Drama, Mystery]  1.794138
# 146      [Action & Adventure, Animation, Crime, Drama]  1.794138
# 368        [Action & Adventure, Crime, Drama, Mystery]  1.794138
# 270                 [Action & Adventure, Crime, Drama]  1.794138
# 161     [Action & Adventure, Animation, Crime, Comedy]  1.771264
# 222                 [Action & Adventure, Crime, Drama]  1.757809
# 498                 [Action & Adventure, Crime, Drama]  1.757809
# 166                 [Action & Adventure, Crime, Drama]  1.757809
# 407                 [Action & Adventure, Crime, Drama]  1.757809
# 830               [Action & Adventure, Comedy, Family]  1.742672
# 606     [Action & Adventure, Animation, Drama, Family]  1.742672
# 140                 [Action & Adventure, Crime, Drama]  1.725517
# 435                 [Action & Adventure, Crime, Drama]  1.725517
# 848     [Animation, Comedy, Sci-Fi & Fantasy, Mystery]  1.705911
# 74                                       [Drama, Soap]  1.705911
# 71                                       [Drama, Soap]  1.705911
# 527                                      [Drama, Soap]  1.205911
# 330                                      [Drama, Soap]  1.205911
# 485  [Action & Adventure, Crime, Drama, War & Polit...  1.169574

# %%
s = movies.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'genre'
genre_movies = movies.drop('genres', axis=1).join(s)

def build_chart(genre, percentile=0.85,limit=5):
    df = genre_movies[genre_movies['genre'] == genre]
    vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = df[df['vote_average'].notnull()]['vote_average'].astype('int')
    C = vote_averages.mean()
    m = vote_counts.quantile(percentile)
    
    qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title','tmdb', 'year', 'vote_count', 'vote_average', 'popularity']]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    
    qualified['wr'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) + (m/(m+x['vote_count']) * C), axis=1)
    qualified = qualified.sort_values('wr', ascending=False)
    qualified = qualified.drop_duplicates(['tmdb']).dropna().head(limit)
    
    return qualified
s.unique()
# Out:
# array(['Crime', 'Drama', 'Comedy', 'Romance', 'Animation', 'Fantasy',
#        'History', 'War', 'Family', 'Thriller', 'Adventure', 'Action',
#        'Western', 'Science Fiction', 'Horror', 'Music', 'Mystery',
#        'TV Movie', 'Documentary'], dtype=object)

# %%
movies['year'] = pd.to_datetime(movies['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
s = movies.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'genre'
genre_movies = movies.drop('genres', axis=1).   join(s)
qualified = genre_movies.groupby(by="genre").sum("vote_average").sort_values(by=['vote_average'],ascending=False)
qualified
# Out:
#                       tmdb  vote_count  vote_average  popularity
# genre
# Drama            138867631         719    708.505602   41034.341
# Action           130839181         678    607.546121   91882.101
# Comedy           131566499         554    583.841006   61068.234
# Animation        104741629         674    572.271412   50062.969
# Adventure         87995362         524    518.210828   65554.819
# Fantasy           67731327         500    465.948230   45861.327
# Family            73163453         584    462.945008   41874.876
# Thriller         101742674         399    388.777237   51978.996
# Romance           63907569         217    314.945938   15205.969
# Crime             51359318         353    215.727067   25317.054
# Science Fiction   55695534         205    197.192250   45611.918
# Mystery           31284163         190    156.573063   14630.435
# Horror            62531857          93    154.858333   22468.677
# Music             16612805          49     68.738095    3882.331
# History           11356867         140     58.110590    3695.618
# War                9919396         195     56.967733    4163.327
# TV Movie          11322142          59     44.609066    1876.000
# Western            6266118          23     19.916667    3048.810
# Documentary        8532027           1      4.000000    2275.261

# %%
movies['overview'] = movies['overview'].fillna("")
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(movies['overview'])
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
moviesSIM = movies.reset_index()
titles = moviesSIM['title']
indices = pd.Series(moviesSIM.index, index=moviesSIM['title'])

# %%
def get_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    try:
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:31]
        movie_indices = [i[0] for i in sim_scores]
        return movies.iloc[movie_indices]
    except Exception as e:
        print(e)
        return []

# %%
get_recommendations("Sing 2")
# Out:
#                             on    tmdb  \
# 356   624d884f87b246f81c48cdbb   10515
# 1171  624d88c661dd768818c973e7  335797
# 812   624d889261dd768818c96ea4  871799
# 517   624d885387b246f81c48cee1   58129
# 983   624d889e61dd768818c97174  588921
# 22    624d882387b246f81c48c933   11216
# 1243  624d88ca61dd768818c97485  278154
# 1201  624d88c761dd768818c97429   38757
# 179   624d883687b246f81c48cba1  347688
# 558   624d885687b246f81c48cf51  537116
# 768   624d886e87b246f81c48d1a9   16761
# 1311  624d88cc61dd768818c9750b   57800
# 605   624d886987b246f81c48cfc3  508439
# 816   624d889261dd768818c96ea8  910596
# 895   624d889861dd768818c97026  950511
# 1354  624d88cd61dd768818c97561   39103
# 753   624d886e87b246f81c48d173  371645
# 1148  624d88ae61dd768818c973ca  811367
# 986   624d889e61dd768818c97178  899082
# 107   624d882787b246f81c48ca8b    8587
# 549   624d885587b246f81c48cf3f    1018
# 344   624d884f87b246f81c48cdab  142061
# 757   624d886e87b246f81c48d17f    5528
# 12    624d882287b246f81c48c8f5  496243
# 666   624d886a87b246f81c48d079  123025
# 945   624d889a61dd768818c970c6  850018
# 991   624d889e61dd768818c97182  618162
# 1284  624d88cb61dd768818c974cf  512200
# 38    624d882487b246f81c48c96f  644479
# 316   624d884187b246f81c48cd59   12104
#
#                                                   title  \
# 356                                   Castle in the Sky
# 1171                                               Sing
# 812                                             Pursuit
# 517                                The Phantom Carriage
# 983                         Ainbo: Spirit of the Amazon
# 22                                      Cinema Paradiso
# 1243                          Ice Age: Collision Course
# 1201                                            Tangled
# 179         Scooby-Doo! and Kiss: Rock and Roll Mystery
# 558                                 tick, tick... BOOM!
# 768                                     A Movie of Eggs
# 1311                         Ice Age: Continental Drift
# 605                                              Onward
# 816                                             Run Gun
# 895           Broken Idol: The Undoing of Diomedes Díaz
# 1354                Dragon Ball Z: The Return of Cooler
# 753                           Hunt for the Wilderpeople
# 1148                                       22 vs. Earth
# 986   Harry Potter 20th Anniversary: Return to Hogwarts
# 107                                       The Lion King
# 549                                    Mulholland Drive
# 344             Batman: The Dark Knight Returns, Part 2
# 757                                          The Chorus
# 12                                             Parasite
# 666             Batman: The Dark Knight Returns, Part 1
# 945                                            Windfall
# 991                                The Harder They Fall
# 1284                            Jumanji: The Next Level
# 38                                   Dedicated to my ex
# 316                                Pink Floyd: The Wall
#
#                                                overview  \
# 356   A young boy and a girl with a magic crystal mu...
# 1171  A koala named Buster recruits his best friend ...
# 812   Detective Breslin crosses paths with Calloway,...
# 517   It's New Year's Eve. Three drunkards evoke a l...
# 983   An epic journey of a young hero and her Spirit...
# 22    A filmmaker recalls his childhood, when he fel...
# 1243  Set after the events of Continental Drift, Scr...
# 1201  When the kingdom's most wanted-and most charmi...
# 179   Get ready to Rock! Scooby-Doo and the Mystery ...
# 558   On the cusp of his 30th birthday, Jonathon Lar...
# 768   A small egg named Toto decides that he wants t...
# 1311  Manny, Diego, and Sid embark upon another adve...
# 605   In a suburban fantasy world, two teenage elf b...
# 816   After leaving a life of crime and violence, Ra...
# 895   This documentary chronicles Diomedes Díaz's ri...
# 1354  Cooler has resurrected himself as a robot and ...
# 753   Ricky is a defiant young city kid who finds hi...
# 1148  Set before the events of ‘Soul’, 22 refuses to...
# 986   An enchanting making-of story told through all...
# 107   A young lion prince is cast out of his pride b...
# 549   Blonde Betty Elms has only just arrived in Hol...
# 344   Batman has stopped the reign of terror that Th...
# 757   Set in 1940s France, a new teacher at a school...
# 12    All unemployed, Ki-taek's family takes peculia...
# 666   Batman has not been seen for ten years. A new ...
# 945   A man breaks into a tech billionaire's empty v...
# 991   Gunning for revenge, outlaw Nat Love saddles u...
# 1284  As the gang return to Jumanji to rescue one of...
# 38    The film tells the story of Ariel, a 21-year-o...
# 316   A troubled rock star descends into madness in ...
#
#                                                  genres  \
# 356   [Animation, Action, Adventure, Fantasy, Family...
# 1171                 [Comedy, Animation, Family, Music]
# 812                           [Crime, Action, Thriller]
# 517                            [Fantasy, Horror, Drama]
# 983             [Animation, Adventure, Fantasy, Family]
# 22                                     [Drama, Romance]
# 1243  [Comedy, Animation, Adventure, Family, Science...
# 1201                                [Animation, Family]
# 179                         [Comedy, Animation, Family]
# 558                                             [Drama]
# 768                                 [Comedy, Animation]
# 1311             [Comedy, Animation, Adventure, Family]
# 605     [Comedy, Animation, Adventure, Fantasy, Family]
# 816                                  [Action, Thriller]
# 895                                       [Documentary]
# 1354               [Animation, Action, Science Fiction]
# 753                          [Comedy, Adventure, Drama]
# 1148               [Comedy, Animation, Fantasy, Family]
# 986                                       [Documentary]
# 107                          [Animation, Family, Drama]
# 549                          [Drama, Mystery, Thriller]
# 344       [Animation, Action, Mystery, Science Fiction]
# 757                                             [Drama]
# 12                            [Comedy, Drama, Thriller]
# 666       [Animation, Action, Mystery, Science Fiction]
# 945                            [Crime, Drama, Thriller]
# 991                                           [Western]
# 1284                       [Comedy, Adventure, Fantasy]
# 38                                      [Comedy, Drama]
# 316                                      [Drama, Music]
#
#                           genres_ids  vote_count  vote_average  popularity  \
# 356   [16, 28, 12, 14, 10751, 10749]           0      0.000000      38.304
# 1171          [35, 16, 10751, 10402]           1      5.000000     113.409
# 812                     [80, 28, 53]           4      1.500000     789.755
# 517                     [14, 27, 18]           0      0.000000      10.610
# 983              [16, 12, 14, 10751]           5      2.800000     179.748
# 22                       [18, 10749]           0      0.000000      18.437
# 1243        [35, 16, 12, 10751, 878]          13      3.538462     118.913
# 1201                     [16, 10751]           0      0.000000     127.542
# 179                  [35, 16, 10751]           2      4.500000      25.199
# 558                             [18]           0      0.000000      76.176
# 768                         [35, 16]           0      0.000000      24.729
# 1311             [35, 16, 12, 10751]           2      3.500000     110.934
# 605          [35, 16, 12, 14, 10751]           6      3.500000      71.644
# 816                         [28, 53]           2      3.000000     742.300
# 895                             [99]           0      0.000000     233.194
# 1354                   [16, 28, 878]           0      0.000000      99.239
# 753                     [35, 12, 18]           1      4.000000      15.572
# 1148             [35, 16, 14, 10751]           6      4.166667     128.921
# 986                             [99]           0      0.000000     162.829
# 107                  [16, 10751, 18]           0      0.000000     169.093
# 549                   [18, 9648, 53]           0      0.000000      27.617
# 344              [16, 28, 9648, 878]           1      5.000000      38.676
# 757                             [18]           0      0.000000      16.875
# 12                      [35, 18, 53]           2      4.500000      97.194
# 666              [16, 28, 9648, 878]           3      4.666667      48.678
# 945                     [80, 18, 53]           2      3.500000     198.969
# 991                             [37]           0      0.000000     172.170
# 1284                    [35, 12, 14]           0      0.000000      99.108
# 38                          [35, 18]           2      4.000000      16.603
# 316                      [18, 10402]           0      0.000000      20.600
#
#      release_date  year
# 356    1986-08-02  1986
# 1171   2016-11-23  2016
# 812    2022-02-18  2022
# 517    1921-01-01  1921
# 983    2021-02-09  2021
# 22     1988-11-17  1988
# 1243   2016-06-23  2016
# 1201   2010-11-24  2010
# 179    2015-07-10  2015
# 558    2021-11-11  2021
# 768    2006-04-21  2006
# 1311   2012-06-27  2012
# 605    2020-02-29  2020
# 816    2022-01-11  2022
# 895    2022-03-30  2022
# 1354   1992-03-07  1992
# 753    2016-03-31  2016
# 1148   2021-04-30  2021
# 986    2022-01-01  2022
# 107    1994-06-23  1994
# 549    2001-06-06  2001
# 344    2013-01-03  2013
# 757    2004-03-17  2004
# 12     2019-05-30  2019
# 666    2012-08-21  2012
# 945    2022-03-11  2022
# 991    2021-10-22  2021
# 1284   2019-12-04  2019
# 38     2019-11-01  2019
# 316    1982-07-14  1982

# %%
getCorelation(65931)
# Out:
#      tmdb  Correlation  rating_counts
# 0   65931     1.000000             17
# 1   68267     1.000000             24
# 2   94810     1.000000             16
# 3   96203     1.000000             12
# 4  135193     0.992778             11
# 5   74440     0.963784             12

# %%
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import stopwords

# %%
plt.subplots(figsize=(12,12))
stop_words = set(stopwords.words('english'))
stop_words.update(',',';','!','?','.','(',')','$','#','+',':','...',' ','')

words=movies['overview'].dropna().apply(nltk.word_tokenize)
word=[]
for i in words:
    word.extend(i)
word=pd.Series(word)
word=([i for i in word.str.lower() if i not in stop_words])
wc = WordCloud(background_color="black", max_words=2000, stopwords=STOPWORDS, max_font_size= 60,width=1000,height=1000)
wc.generate(" ".join(word))
plt.imshow(wc)
plt.axis('off')
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import seaborn
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import NearestNeighbors

# %%
knn_ratings = ratings[["userId","on","rate"]]
knn_movies = movies[["on","tmdb"]]
knn_movie_ratings = pd.merge(knn_movies,knn_ratings,on="on")

# %%
movie_rating_count = (knn_movie_ratings.
                      groupby(by=["tmdb"])["rate"].
                      count().reset_index().
                      rename(columns={'rate':'totalRating'})
                      [["tmdb","totalRating"]]
                     )
movie_rating_count
# Out:
#        tmdb  totalRating
# 0     46639            1
# 1     60059            1
# 2     61889            6
# 3     61901            1
# 4     61923            4
# ..      ...          ...
# 270  158307            2
# 271  158415            2
# 272  194495            2
# 273  196810            2
# 274  196812            1
#
# [275 rows x 2 columns]

# %%
rating_with_totalRatingCount=knn_movie_ratings.merge(movie_rating_count,left_on='tmdb',right_on='tmdb',how="inner")
rating_with_totalRatingCount.head()
rating_with_totalRatingCount.info()
rating_with_totalRatingCount.describe()
rating_with_totalRatingCount['totalRating'].count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820 entries, 0 to 819
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   on           820 non-null    object
#  1   tmdb         820 non-null    int64
#  2   userId       820 non-null    object
#  3   rate         820 non-null    int64
#  4   totalRating  820 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 38.4+ KB
# 820

# %%
popularity_threshold=10
#rating_popular_book=rating_with_totalRatingCount.query('totalRatingCount>=@popularity_threshold')
rating_popular_movie=rating_with_totalRatingCount[rating_with_totalRatingCount['totalRating']>popularity_threshold]
rating_popular_movie.head()
# Out:
#                           on    tmdb                    userId  rate  \
# 75  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     3
# 76  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     4
# 77  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     2
# 78  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     2
# 79  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     3
#
#     totalRating
# 75           49
# 76           49
# 77           49
# 78           49
# 79           49

# %%
from scipy.sparse import csr_matrix
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import NearestNeighbors

combined = rating_popular_movie.merge(users,left_on='userId',right_on='_id',how="inner")
combined = combined.drop_duplicates(['userId','tmdb'])

# %%
knn_users = combined.pivot(index="tmdb",columns="_id",values="rate").fillna(0)
knn_rating_user_csr = csr_matrix(knn_users.values)

# %%
from sklearn.neighbors import NearestNeighbors
model_knn=NearestNeighbors(metric="cosine",algorithm="brute")
model_knn.fit(knn_rating_user_csr)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query_index=4
distances,indices=model_knn.kneighbors(knn_users.iloc[query_index,:].values.reshape(1,-1),n_neighbors=5)
print("Distances -->",distances," Indices -->",indices)
 
print(distances.flatten())
print(len(distances.flatten()))
 
for i in range(0,len(distances.flatten())):
    if i==0:
        print("Recommendation for {0}:\n".format(knn_users.index[query_index]))
    else:
        print("{0}: {1}, with distance of {2}:".format(i,knn_users.index[indices.flatten()[i]],distances.flatten()[i]))
# Out:
# Distances --> [[0.         0.01869324 0.25956776 0.3513507  0.38616558]]  Indices --> [[4 3 5 1 6]]
# [0.         0.01869324 0.25956776 0.3513507  0.38616558]
# 5
# Recommendation for 78173:
#
# 1: 77184, with distance of 0.018693237074683733:
# 2: 91425, with distance of 0.2595677642771602:
# 3: 68267, with distance of 0.351350695101027:
# 4: 94810, with distance of 0.38616557702699883:

# %%
query_index=68267
new_shape = knn_users.reset_index()
values = new_shape[new_shape["tmdb"] == query_index].drop(columns=['tmdb']).values.reshape(1,-1)

distances,indices=model_knn.kneighbors(values,n_neighbors=5)
print("Distances -->",distances," Indices -->",indices)
 
print(distances.flatten())
print(len(distances.flatten()))
 
for i in range(0,len(distances.flatten())):
    if i==0:
        print("Recommendation for {0}:\n".format(query_index))
    else:
        print("{0}: {1}, with distance of {2}:".format(i,knn_users.index[indices.flatten()[i]],distances.flatten()[i]))
# Out:
# Distances --> [[0.         0.21476779 0.32828339 0.34277357 0.3513507 ]]  Indices --> [[1 6 9 5 4]]
# [0.         0.21476779 0.32828339 0.34277357 0.3513507 ]
# 5
# Recommendation for 68267:
#
# 1: 94810, with distance of 0.21476778908134353:
# 2: 123566, with distance of 0.32828338672015145:
# 3: 91425, with distance of 0.34277356680596194:
# 4: 78173, with distance of 0.351350695101027:

# %%
knn_users
# Out:
# _id     625495df8ca5e225e5473995  625499768ca5e225e5475a58  \
# tmdb
# 65931                        0.0                       4.0
# 68267                        0.0                       0.0
# 74440                        0.0                       4.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       0.0
# 94810                        0.0                       0.0
# 96203                        0.0                       0.0
# 115304                       5.0                       0.0
# 123566                       0.0                       0.0
# 135193                       0.0                       4.0
# 154490                       0.0                       0.0
#
# _id     6254b1e98ca5e225e548c632  6254b3e18ca5e225e548ce58  \
# tmdb
# 65931                        3.0                       3.0
# 68267                        0.0                       3.0
# 74440                        0.0                       0.0
# 77184                        0.0                       3.0
# 78173                        0.0                       3.0
# 91425                        0.0                       3.0
# 94810                        0.0                       3.0
# 96203                        0.0                       3.0
# 115304                       0.0                       0.0
# 123566                       0.0                       0.0
# 135193                       3.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6254c08d8ca5e225e5494015  62556c3b8ca5e225e549587e  \
# tmdb
# 65931                        0.0                       3.0
# 68267                        0.0                       0.0
# 74440                        3.0                       0.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       0.0
# 94810                        0.0                       0.0
# 96203                        0.0                       0.0
# 115304                       0.0                       0.0
# 123566                       0.0                       3.0
# 135193                       1.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6258a7df6ae20c911ad38f9f  625f35c0ed892b917c5c8be3  \
# tmdb
# 65931                        0.0                       0.0
# 68267                        0.0                       0.0
# 74440                        0.0                       0.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       5.0
# 94810                        0.0                       0.0
# 96203                        0.0                       0.0
# 115304                       0.0                       0.0
# 123566                       3.0                       0.0
# 135193                       0.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6263e8f3fd2ee90bb8a2c7f7  6263e96efd2ee90bb8a2cfee  \
# tmdb
# 65931                        0.0                       5.0
# 68267                        0.0                       4.0
# 74440                        0.0                       3.0
# 77184                        4.0                       0.0
# 78173                        3.0                       0.0
# 91425                        5.0                       0.0
# 94810                        0.0                       5.0
# 96203                        0.0                       0.0
# 115304                       0.0                       4.0
# 123566                       0.0                       0.0
# 135193                       0.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6263e99bfd2ee90bb8a2d0ac  6263e9b3fd2ee90bb8a2d0b2  \
# tmdb
# 65931                        0.0                       0.0
# 68267                        0.0                       4.0
# 74440                        0.0                       0.0
# 77184                        0.0                       5.0
# 78173                        0.0                       5.0
# 91425                        0.0                       5.0
# 94810                        0.0                       5.0
# 96203                        0.0                       0.0
# 115304                       0.0                       0.0
# 123566                       0.0                       5.0
# 135193                       2.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6263e9d2fd2ee90bb8a2d0b6  6263e9f2fd2ee90bb8a2d0bb  \
# tmdb
# 65931                        0.0                       0.0
# 68267                        0.0                       4.0
# 74440                        0.0                       5.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       5.0
# 94810                        0.0                       0.0
# 96203                        0.0                       5.0
# 115304                       0.0                       0.0
# 123566                       0.0                       4.0
# 135193                       0.0                       3.0
# 154490                       3.0                       0.0
#
# _id     6263ea19fd2ee90bb8a2d0bf  6263ea32fd2ee90bb8a2d0c3  \
# tmdb
# 65931                        0.0                       2.0
# 68267                        0.0                       0.0
# 74440                        0.0                       0.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       0.0
# 94810                        0.0                       0.0
# 96203                        3.0                       3.0
# 115304                       0.0                       0.0
# 123566                       0.0                       0.0
# 135193                       0.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6263ea3efd2ee90bb8a2d0c7
# tmdb
# 65931                        0.0
# 68267                        3.0
# 74440                        0.0
# 77184                        2.0
# 78173                        3.0
# 91425                        3.0
# 94810                        0.0
# 96203                        0.0
# 115304                       0.0
# 123566                       3.0
# 135193                       0.0
# 154490                       0.0

# %%
knn_users.iloc[query_index,:].values.reshape(1,-1)
# Out:
# array([[5., 0., 0., 0., 0., 4., 0.]])

# %%
knn_users.reset_index()[knn_users.reset_index()["tmdb"] == 719088]
# Out:
# _id    tmdb  625495df8ca5e225e5473995  625499768ca5e225e5475a58  \
# 90   719088                       3.0                       0.0
#
# _id  6254b1e98ca5e225e548c632  6254b3e18ca5e225e548ce58  \
# 90                        0.0                       0.0
#
# _id  6254c08d8ca5e225e5494015  62556c3b8ca5e225e549587e  \
# 90                        0.0                       2.0
#
# _id  62582dc212014fc3392d66a1
# 90                        0.0

# %%
s = movies.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'genre'
genre_movies = movies.drop('genres', axis=1).join(s)

df = genre_movies
vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = df[df['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()
m = vote_counts.quantile(0.85)

qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title','tmdb', 'year', 'vote_count', 'genre' , 'vote_average', 'popularity']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')

qualified['wr'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) + (m/(m+x['vote_count']) * C), axis=1)
qualified = qualified.sort_values('wr', ascending=False)
qualified = qualified

# %%
qualified.groupby(by="genre").sum("vote_average").sort_values(by=['vote_average'],ascending=False)
# Out:
#                       tmdb  vote_count  vote_average  popularity          wr
# genre
# Drama            118818178        1644           344   31205.530  302.750176
# Comedy           113532636         780           306   51948.972  254.051715
# Animation         78484872         812           194   40159.238  176.619513
# Crime             63263552        1582           194   31937.386  178.304616
# Family            62187876         584           166   36267.788  146.636988
# Romance           39926331         383           120    7177.831  102.351083
# Action            37679810         793           109   15763.500   99.167990
# Thriller          34697353         738            90   14918.536   83.260458
# Fantasy           26615362         315            75   17253.867   67.690851
# Adventure         23272207         236            66    9567.067   59.284420
# TV Movie           8540326         118            28    1486.227   25.527312
# History            7389627         107            28    1991.533   25.049413
# Music              9146931         106            24    2268.742   22.168302
# Mystery           11872526         198            20    5254.410   19.797227
# Science Fiction    5557523          35            15    1264.416   11.917702
# Horror             7941613          52            14    1893.308   12.391560
# War                1931026          15             5     320.721    4.135138

# %%
import mongodb as md

# %%
md.read_mongo("finalyearproject","movies","online")
# Out:
#                            _id    tmdb                          title  \
# 0     624d882287b246f81c48c8b1     278       The Shawshank Redemption
# 1     624d882287b246f81c48c8b3   19404    Dilwale Dulhania Le Jayenge
# 2     624d882287b246f81c48c8b5     238                  The Godfather
# 3     624d882287b246f81c48c8b7  652837  Josee, the Tiger and the Fish
# 4     624d882287b246f81c48c8cf  533514   Violet Evergarden: The Movie
# ...                        ...     ...                            ...
# 1464  624d88d361dd768818c97646   16996                       17 Again
# 1465  624d88d361dd768818c9763a  141052                 Justice League
# 1466  624d88d361dd768818c9763e  102899                        Ant-Man
# 1467  624d88d361dd768818c97644   44912                  Green Lantern
# 1468  624d88d361dd768818c9763c  433945                    Tokyo Ghoul
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     With dreams of diving abroad, Tsuneo gets a jo...
# 4     As the world moves on from the war and technol...
# ...                                                 ...
# 1464  On the brink of a midlife crisis, 30-something...
# 1465  Fuelled by his restored faith in humanity and ...
# 1466  Armed with the astonishing ability to shrink i...
# 1467  For centuries, a small but powerful force of w...
# 1468  A Tokyo college student is attacked by a ghoul...
#
#                                                  genres  vote_count  \
# 0                          [Crime, Drama, Crime, Drama]           0
# 1               [Comedy, Drama, Romance, Drama, Comedy]           0
# 2                          [Crime, Drama, Crime, Drama]           0
# 3         [Animation, Drama, Romance, Animation, Drama]           6
# 4     [Animation, Fantasy, Drama, Romance, Animation...           9
# ...                                                 ...         ...
# 1464                                   [Comedy, Comedy]           0
# 1465      [Action, Adventure, Fantasy, Science Fiction]           0
# 1466               [Action, Adventure, Science Fiction]           0
# 1467     [Action, Adventure, Thriller, Science Fiction]           0
# 1468           [Action, Horror, Drama, Thriller, Drama]           0
#
#       vote_average  popularity release_date
# 0         0.000000      78.147   1994-09-23
# 1         0.000000      29.896   1995-10-20
# 2         0.000000      91.215   1972-03-14
# 3         2.500000      30.509   2020-12-25
# 4         1.555556      42.120   2020-09-18
# ...            ...         ...          ...
# 1464      0.000000      91.448   2009-03-11
# 1465      0.000000      80.543   2017-11-15
# 1466      0.000000      86.827   2015-07-14
# 1467      0.000000      86.645   2011-06-16
# 1468      0.000000      82.517   2017-07-16
#
# [1469 rows x 9 columns]
