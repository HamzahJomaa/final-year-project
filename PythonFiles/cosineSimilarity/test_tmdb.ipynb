# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from surprise import Reader, Dataset, SVD
import mongodb as md

import warnings; warnings.simplefilter('ignore')

# %%
movies = md.read_mongo("finalyearproject","series",True)
ratings = md.read_mongo("finalyearproject","reviews",True)
users = md.read_mongo("finalyearproject","users",True)
movies = movies.rename(columns={"_id":"on"})
movie_ratings = pd.merge(movies,ratings,on="on")
movies['year'] = pd.to_datetime(movies['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
movies_ratings = movie_ratings.rename(columns={"title_x":"movieTitle","title_y":"rateTitle"})
movies
# Out:
#                             on    tmdb                title  \
# 0     625c92651b4a8150b1b27e74   76669                Elite
# 1     625c92651b4a8150b1b27e70   92749          Moon Knight
# 2     625c92651b4a8150b1b27e76  102045           The Choice
# 3     625c92651b4a8150b1b27e72   52814                 Halo
# 4     625c92651b4a8150b1b27e78  121745           Till Death
# ...                        ...     ...                  ...
# 1010  625c935c100ec9922fdfaebd   45016           The Bridge
# 1011  625c935c100ec9922fdfaebf   42445               Borgen
# 1012  625c935c100ec9922fdfaec1   70540            Andi Mack
# 1013  625c935c100ec9922fdfaec3    1457  Pride and Prejudice
# 1014  625c935c100ec9922fdfaec5   62227             Triage X
#
#                                                overview  \
# 0     When three working class kids enroll in the mo...
# 1     When Steven Grant, a mild-mannered gift-shop e...
# 2     The story of Ahmed Saber Al-Mansi, commander o...
# 3     Depicting an epic 26th-century conflict betwee...
# 4     Fed up with his wife’s distancing from him, Ha...
# ...                                                 ...
# 1010  When a body is found on the bridge between Den...
# 1011  40-year old political leader Birgitte Nyborg s...
# 1012  Andi is contemplative and artistic and shelter...
# 1013  Set in England in the early 19th century, Prid...
# 1014  Mochizuki General Hospital boasts some of the ...
#
#                                              genres          genres_ids  \
# 0                           [Crime, Drama, Mystery]      [80, 18, 9648]
# 1     [Action & Adventure, Drama, Sci-Fi & Fantasy]  [10759, 18, 10765]
# 2       [Action & Adventure, Drama, War & Politics]  [10759, 18, 10768]
# 3            [Action & Adventure, Sci-Fi & Fantasy]      [10759, 10765]
# 4                                           [Drama]                [18]
# ...                                             ...                 ...
# 1010                               [Crime, Mystery]          [80, 9648]
# 1011                                        [Drama]                [18]
# 1012                        [Drama, Comedy, Family]     [18, 35, 10751]
# 1013                                        [Drama]                [18]
# 1014                [Action & Adventure, Animation]         [10759, 16]
#
#       vote_count  vote_average  popularity release_date  year
# 0              2      4.500000    2644.519   2018-10-05  2018
# 1              1      4.000000   11136.738   2022-03-30  2022
# 2              3      2.333333    1618.854   2020-04-24  2020
# 3              0      0.000000    9703.440   2022-03-24  2022
# 4              0      0.000000    1507.532   2021-04-13  2021
# ...          ...           ...         ...          ...   ...
# 1010           0      0.000000      40.607   2011-09-21  2011
# 1011           0      0.000000      34.841   2010-09-26  2010
# 1012           2      5.000000      25.730   2017-03-07  2017
# 1013           0      0.000000      56.686   1995-09-24  1995
# 1014           0      0.000000      15.227   2015-04-09  2015
#
# [1015 rows x 11 columns]

# %%
vote_counts = movies[movies['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = movies[movies['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()

m = vote_counts.quantile(0.95)


qualified = movies[(movies['vote_count'] >= m) & (movies['vote_count'].notnull()) & (movies['vote_average'].notnull())][['tmdb','title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')

def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

qualified['wr'] = qualified.apply(weighted_rating, axis=1)
qualified = qualified.sort_values('wr', ascending=False)
qualified
# Out:
#        tmdb                                title  year  vote_count  \
# 544   94810        Adventure Time: Distant Lands  2020          16
# 445  115304                   Disney Intertwined  2021          15
# 118  154490  From the Second Side with Guy Zohar  2019          48
# 482   68267       Trollhunters: Tales of Arcadia  2016          24
# 606  123566                         Metal Family  2018          23
# 767   95599     Kipo and the Age of Wonderbeasts  2020           5
# 386   79061                   Craig of the Creek  2018           5
# 381  110316                  Alice in Borderland  2020           5
# 793   99778               The God of High School  2020           5
# 676   91425                       Infinity Train  2019          12
# 781   74440                         Harley Quinn  2019          12
# 975   96203                             Gleipnir  2020          12
# 429   61923          Star vs. the Forces of Evil  2015           4
# 847  105797            Wizards: Tales of Arcadia  2020           4
# 351   93741      Jurassic World: Camp Cretaceous  2020           4
# 607   83097               The Promised Neverland  2019           9
# 141   75219                                9-1-1  2018           9
# 349   74682                     I Am Not a Robot  2017           9
# 32    71790                             S.W.A.T.  2017           9
# 938   94280               Steven Universe Future  2019           8
# 965   73946                Inuyashiki: Last Hero  2017           8
# 393  103409                    World's End Harem  2021           8
# 577   78004           Death Note: New Generation  2016           7
# 997   94795           Cagaster of an Insect Cage  2020           7
# 705   97860                         Tower of God  2020           6
# 498   67116                        Lethal Weapon  2016           6
# 609   80564                          Banana Fish  2018           5
# 696   94404                           Dorohedoro  2020           4
# 395   78191                                  You  2018           4
# 454   99071                       Redo of Healer  2021           4
# 952   87491                  DC Super Hero Girls  2019           4
# 297   75450                               Titans  2018           4
# 219   94605                               Arcane  2021           4
# 226   77184              Halo: The Fall of Reach  2015          20
# 786   65931                     Bungo Stray Dogs  2016          17
# 991   78173            Dragons: Race to the Edge  2015          13
# 485  135193           Malverde: The Patron Saint  2021          11
# 146  105009                      Tokyo Revengers  2021           9
# 407   62710                            Blindspot  2015           9
# 270   80748                                  FBI  2018           9
# 368  110356                              My Name  2021           9
# 435   67178                Marvel's The Punisher  2017           8
# 210   82809                      Falsa identidad  2018           7
# 166   89393                     9-1-1: Lone Star  2020           7
# 50   108978                              Reacher  2022           7
# 253   61889                   Marvel's Daredevil  2015           6
# 88    67335             Sin senos sí hay paraíso  2016           6
# 193   71789                            SEAL Team  2017           4
# 969   82817                         Go Go Squid!  2019           4
# 30   116135                    Vikings: Valhalla  2022           4
# 95    80623                                 BAKI  2018           7
# 527   66579               The Three Sides of Ana  2016           5
#
#      vote_average  popularity  \
# 544             4      94.913
# 445             4     110.056
# 118             3     308.512
# 482             3     104.666
# 606             3      62.279
# 767             4      23.019
# 386             4     123.213
# 381             4     124.256
# 793             4      53.436
# 676             3      34.164
# 781             3      53.952
# 975             3      25.693
# 429             4     113.907
# 847             4      35.986
# 351             4     131.997
# 607             3      77.933
# 141             3     253.901
# 349             3     133.341
# 32              3     831.289
# 938             3      60.998
# 965             3       7.533
# 393             3     122.050
# 577             3      90.468
# 997             3      20.240
# 705             3      39.368
# 498             3     103.200
# 609             3      55.489
# 696             3      32.288
# 395             3     121.086
# 454             3     107.355
# 952             3      20.998
# 297             3     159.312
# 219             3     196.522
# 226             2     192.103
# 786             2      56.469
# 991             2      62.374
# 485             2     103.894
# 146             2     249.271
# 407             2     118.226
# 270             2     172.574
# 368             2     127.085
# 435             2     112.172
# 210             2     199.743
# 166             2     232.430
# 50              2     537.137
# 253             2     174.029
# 88              2     363.884
# 193             2     210.145
# 969             2      39.476
# 30              2     849.834
# 95              1     347.778
# 527             1      96.987
#
#                                                 genres        wr
# 544      [Animation, Comedy, Family, Sci-Fi & Fantasy]  3.386207
# 445          [Drama, Comedy, Family, Sci-Fi & Fantasy]  3.353902
# 118                             [News, War & Politics]  2.840849
# 482  [Action & Adventure, Animation, Comedy, Family...  2.704433
# 606     [Action & Adventure, Animation, Drama, Family]  2.693487
# 767              [Action & Adventure, Animation, Kids]  2.636015
# 386                          [Animation, Comedy, Kids]  2.636015
# 381  [Action & Adventure, Drama, Sci-Fi & Fantasy, ...  2.636015
# 793  [Action & Adventure, Animation, Comedy, Sci-Fi...  2.636015
# 676  [Action & Adventure, Animation, Kids, Family, ...  2.482759
# 781  [Action & Adventure, Animation, Crime, Comedy,...  2.482759
# 975  [Action & Adventure, Animation, Comedy, Sci-Fi...  2.482759
# 429  [Action & Adventure, Animation, Comedy, Sci-Fi...  2.465517
# 847  [Action & Adventure, Animation, Comedy, Sci-Fi...  2.465517
# 351              [Action & Adventure, Animation, Kids]  2.465517
# 607  [Action & Adventure, Animation, Drama, Sci-Fi ...  2.363395
# 141                 [Action & Adventure, Crime, Drama]  2.363395
# 349          [Drama, Comedy, Family, Sci-Fi & Fantasy]  2.363395
# 32                  [Action & Adventure, Crime, Drama]  2.363395
# 938  [Action & Adventure, Animation, Drama, Comedy,...  2.310345
# 965  [Action & Adventure, Animation, Crime, Drama, ...  2.310345
# 393  [Action & Adventure, Animation, Drama, Sci-Fi ...  2.310345
# 577                            [Crime, Drama, Mystery]  2.247649
# 997  [Action & Adventure, Animation, Drama, Sci-Fi ...  2.247649
# 705  [Action & Adventure, Animation, Drama, Sci-Fi ...  2.172414
# 498                 [Action & Adventure, Crime, Drama]  2.172414
# 609    [Action & Adventure, Animation, Drama, Mystery]  2.080460
# 696  [Action & Adventure, Animation, Comedy, Sci-Fi...  1.965517
# 395                            [Crime, Drama, Mystery]  1.965517
# 454  [Action & Adventure, Animation, Crime, Drama, ...  1.965517
# 952        [Animation, Kids, Family, Sci-Fi & Fantasy]  1.965517
# 297      [Action & Adventure, Drama, Sci-Fi & Fantasy]  1.965517
# 219  [Action & Adventure, Animation, Drama, Sci-Fi ...  1.965517
# 226  [Action & Adventure, Animation, Family, Sci-Fi...  1.821839
# 786  [Action & Adventure, Animation, Crime, Drama, ...  1.796388
# 991  [Action & Adventure, Animation, Kids, Family, ...  1.748479
# 485  [Action & Adventure, Crime, Drama, War & Polit...  1.714943
# 146      [Action & Adventure, Animation, Crime, Drama]  1.671088
# 407                 [Action & Adventure, Crime, Drama]  1.671088
# 270                 [Action & Adventure, Crime, Drama]  1.671088
# 368        [Action & Adventure, Crime, Drama, Mystery]  1.671088
# 435                 [Action & Adventure, Crime, Drama]  1.643678
# 210                        [Action & Adventure, Crime]  1.611285
# 166                 [Action & Adventure, Crime, Drama]  1.611285
# 50         [Action & Adventure, Crime, Drama, Mystery]  1.611285
# 253                 [Action & Adventure, Crime, Drama]  1.572414
# 88         [Action & Adventure, Crime, Drama, Mystery]  1.572414
# 193        [Action & Adventure, Drama, War & Politics]  1.465517
# 969                              [Drama, Comedy, Soap]  1.465517
# 30         [Action & Adventure, Drama, War & Politics]  1.465517
# 95       [Action & Adventure, Animation, Crime, Drama]  0.974922
# 527                                      [Drama, Soap]  0.969349

# %%
s = movies.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'genre'
genre_movies = movies.drop('genres', axis=1).join(s)

def build_chart(genre, percentile=0.85,limit=5):
    df = genre_movies[genre_movies['genre'] == genre]
    vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = df[df['vote_average'].notnull()]['vote_average'].astype('int')
    C = vote_averages.mean()
    m = vote_counts.quantile(percentile)
    
    qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title','tmdb', 'year', 'vote_count', 'vote_average', 'popularity']]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    
    qualified['wr'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) + (m/(m+x['vote_count']) * C), axis=1)
    qualified = qualified.sort_values('wr', ascending=False)
    qualified = qualified.drop_duplicates(['tmdb']).dropna().head(limit)
    
    return qualified
build_chart("Drama")
# Out:
#                                                  title    tmdb  year  \
# 445                                 Disney Intertwined  115304  2021
# 381                                Alice in Borderland  110316  2020
# 399                                              Lupin   96677  2021
# 814  WorldEnd: What are you doing at the end of the...   70639  2017
# 644                                       Love, Victor   97186  2020
#
#      vote_count  vote_average  popularity        wr
# 445          15             4     110.056  3.655523
# 381           5             4     124.256  3.163412
# 399           2             5     119.945  3.035971
# 814           2             5      22.596  3.035971
# 644           2             5      64.664  3.035971

# %%
movies['year'] = pd.to_datetime(movies['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
s = movies.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'genre'
genre_movies = movies.drop('genres', axis=1).   join(s)
qualified = genre_movies.groupby(by="genre").sum("vote_average").sort_values(by=['vote_average'],ascending=False)
qualified
# Out:
#                           title    tmdb  year  vote_count  vote_average  \
# 838                Prodigal Son   91875  2019           4             3
# 50                      Reacher  108978  2022          36             2
# 485  Malverde: The Patron Saint  135193  2021          26             2
# 893            Mare of Easttown  115004  2021           9             2
# 781                Harley Quinn   74440  2019          26             2
#
#      popularity   wr
# 838      34.189  3.0
# 50      537.137  2.0
# 485     103.894  2.0
# 893      63.861  2.0
# 781      53.952  2.0

# %%
movies['overview'] = movies['overview'].fillna("")
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(movies['overview'])
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
moviesSIM = movies.reset_index()
titles = moviesSIM['title']
indices = pd.Series(moviesSIM.index, index=moviesSIM['title'])

# %%
def get_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    return movies.iloc[movie_indices]

# %%
user_movie_rating = movies_ratings.pivot_table(index='userId', columns='tmdb', values='rate')
ratings_mean_count = pd.DataFrame(movies_ratings.groupby('tmdb')['rate'].mean())
ratings_mean_count['rating_counts'] = pd.DataFrame(movies_ratings.groupby('tmdb')['rate'].count())

def getCorelation(tmdb):
    movieSelected = user_movie_rating[tmdb]
    movieCorrelation = user_movie_rating.corrwith(movieSelected,method="pearson")
    df_movieCorrelation = pd.DataFrame(movieCorrelation, columns=['Correlation'])
    df_movieCorrelation.dropna(inplace=True)
    df_movieCorrelation = df_movieCorrelation.join(ratings_mean_count['rating_counts'])
    df_movieCorrelation = df_movieCorrelation[df_movieCorrelation ['rating_counts']>10].sort_values('Correlation', ascending=False)
    df_movieCorrelation = df_movieCorrelation.reset_index()
    return df_movieCorrelation

# %%
getCorelation(65931)
# Out:
#      tmdb  Correlation  rating_counts
# 0   65931     1.000000             17
# 1   68267     1.000000             24
# 2   94810     1.000000             16
# 3   96203     1.000000             12
# 4  135193     0.992778             11
# 5   74440     0.963784             12

# %%
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import stopwords

# %%
plt.subplots(figsize=(12,12))
stop_words = set(stopwords.words('english'))
stop_words.update(',',';','!','?','.','(',')','$','#','+',':','...',' ','')

words=movies['overview'].dropna().apply(nltk.word_tokenize)
word=[]
for i in words:
    word.extend(i)
word=pd.Series(word)
word=([i for i in word.str.lower() if i not in stop_words])
wc = WordCloud(background_color="black", max_words=2000, stopwords=STOPWORDS, max_font_size= 60,width=1000,height=1000)
wc.generate(" ".join(word))
plt.imshow(wc)
plt.axis('off')
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import seaborn
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import NearestNeighbors

# %%
knn_ratings = ratings[["userId","on","rate"]]
knn_movies = movies[["on","tmdb"]]
knn_movie_ratings = pd.merge(knn_movies,knn_ratings,on="on")

# %%
movie_rating_count = (knn_movie_ratings.
                      groupby(by=["tmdb"])["rate"].
                      count().reset_index().
                      rename(columns={'rate':'totalRating'})
                      [["tmdb","totalRating"]]
                     )
movie_rating_count
# Out:
#        tmdb  totalRating
# 0     46639            1
# 1     60059            1
# 2     61889            6
# 3     61901            1
# 4     61923            4
# ..      ...          ...
# 270  158307            2
# 271  158415            2
# 272  194495            2
# 273  196810            2
# 274  196812            1
#
# [275 rows x 2 columns]

# %%
rating_with_totalRatingCount=knn_movie_ratings.merge(movie_rating_count,left_on='tmdb',right_on='tmdb',how="inner")
rating_with_totalRatingCount.head()
rating_with_totalRatingCount.info()
rating_with_totalRatingCount.describe()
rating_with_totalRatingCount['totalRating'].count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820 entries, 0 to 819
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   on           820 non-null    object
#  1   tmdb         820 non-null    int64
#  2   userId       820 non-null    object
#  3   rate         820 non-null    int64
#  4   totalRating  820 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 38.4+ KB
# 820

# %%
popularity_threshold=10
#rating_popular_book=rating_with_totalRatingCount.query('totalRatingCount>=@popularity_threshold')
rating_popular_movie=rating_with_totalRatingCount[rating_with_totalRatingCount['totalRating']>popularity_threshold]
rating_popular_movie.head()
# Out:
#                           on    tmdb                    userId  rate  \
# 75  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     3
# 76  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     4
# 77  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     2
# 78  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     2
# 79  625c926c1b4a8150b1b28101  154490  6263e9d2fd2ee90bb8a2d0b6     3
#
#     totalRating
# 75           49
# 76           49
# 77           49
# 78           49
# 79           49

# %%
from scipy.sparse import csr_matrix
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import NearestNeighbors

combined = rating_popular_movie.merge(users,left_on='userId',right_on='_id',how="inner")
combined = combined.drop_duplicates(['userId','tmdb'])

# %%
knn_users = combined.pivot(index="tmdb",columns="_id",values="rate").fillna(0)
knn_rating_user_csr = csr_matrix(knn_users.values)

# %%
from sklearn.neighbors import NearestNeighbors
model_knn=NearestNeighbors(metric="cosine",algorithm="brute")
model_knn.fit(knn_rating_user_csr)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query_index=4
distances,indices=model_knn.kneighbors(knn_users.iloc[query_index,:].values.reshape(1,-1),n_neighbors=5)
print("Distances -->",distances," Indices -->",indices)
 
print(distances.flatten())
print(len(distances.flatten()))
 
for i in range(0,len(distances.flatten())):
    if i==0:
        print("Recommendation for {0}:\n".format(knn_users.index[query_index]))
    else:
        print("{0}: {1}, with distance of {2}:".format(i,knn_users.index[indices.flatten()[i]],distances.flatten()[i]))
# Out:
# Distances --> [[0.         0.01869324 0.25956776 0.3513507  0.38616558]]  Indices --> [[4 3 5 1 6]]
# [0.         0.01869324 0.25956776 0.3513507  0.38616558]
# 5
# Recommendation for 78173:
#
# 1: 77184, with distance of 0.018693237074683733:
# 2: 91425, with distance of 0.2595677642771602:
# 3: 68267, with distance of 0.351350695101027:
# 4: 94810, with distance of 0.38616557702699883:

# %%
query_index=68267
new_shape = knn_users.reset_index()
values = new_shape[new_shape["tmdb"] == query_index].drop(columns=['tmdb']).values.reshape(1,-1)

distances,indices=model_knn.kneighbors(values,n_neighbors=5)
print("Distances -->",distances," Indices -->",indices)
 
print(distances.flatten())
print(len(distances.flatten()))
 
for i in range(0,len(distances.flatten())):
    if i==0:
        print("Recommendation for {0}:\n".format(query_index))
    else:
        print("{0}: {1}, with distance of {2}:".format(i,knn_users.index[indices.flatten()[i]],distances.flatten()[i]))
# Out:
# Distances --> [[0.         0.21476779 0.32828339 0.34277357 0.3513507 ]]  Indices --> [[1 6 9 5 4]]
# [0.         0.21476779 0.32828339 0.34277357 0.3513507 ]
# 5
# Recommendation for 68267:
#
# 1: 94810, with distance of 0.21476778908134353:
# 2: 123566, with distance of 0.32828338672015145:
# 3: 91425, with distance of 0.34277356680596194:
# 4: 78173, with distance of 0.351350695101027:

# %%
knn_users
# Out:
# _id     625495df8ca5e225e5473995  625499768ca5e225e5475a58  \
# tmdb
# 65931                        0.0                       4.0
# 68267                        0.0                       0.0
# 74440                        0.0                       4.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       0.0
# 94810                        0.0                       0.0
# 96203                        0.0                       0.0
# 115304                       5.0                       0.0
# 123566                       0.0                       0.0
# 135193                       0.0                       4.0
# 154490                       0.0                       0.0
#
# _id     6254b1e98ca5e225e548c632  6254b3e18ca5e225e548ce58  \
# tmdb
# 65931                        3.0                       3.0
# 68267                        0.0                       3.0
# 74440                        0.0                       0.0
# 77184                        0.0                       3.0
# 78173                        0.0                       3.0
# 91425                        0.0                       3.0
# 94810                        0.0                       3.0
# 96203                        0.0                       3.0
# 115304                       0.0                       0.0
# 123566                       0.0                       0.0
# 135193                       3.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6254c08d8ca5e225e5494015  62556c3b8ca5e225e549587e  \
# tmdb
# 65931                        0.0                       3.0
# 68267                        0.0                       0.0
# 74440                        3.0                       0.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       0.0
# 94810                        0.0                       0.0
# 96203                        0.0                       0.0
# 115304                       0.0                       0.0
# 123566                       0.0                       3.0
# 135193                       1.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6258a7df6ae20c911ad38f9f  625f35c0ed892b917c5c8be3  \
# tmdb
# 65931                        0.0                       0.0
# 68267                        0.0                       0.0
# 74440                        0.0                       0.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       5.0
# 94810                        0.0                       0.0
# 96203                        0.0                       0.0
# 115304                       0.0                       0.0
# 123566                       3.0                       0.0
# 135193                       0.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6263e8f3fd2ee90bb8a2c7f7  6263e96efd2ee90bb8a2cfee  \
# tmdb
# 65931                        0.0                       5.0
# 68267                        0.0                       4.0
# 74440                        0.0                       3.0
# 77184                        4.0                       0.0
# 78173                        3.0                       0.0
# 91425                        5.0                       0.0
# 94810                        0.0                       5.0
# 96203                        0.0                       0.0
# 115304                       0.0                       4.0
# 123566                       0.0                       0.0
# 135193                       0.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6263e99bfd2ee90bb8a2d0ac  6263e9b3fd2ee90bb8a2d0b2  \
# tmdb
# 65931                        0.0                       0.0
# 68267                        0.0                       4.0
# 74440                        0.0                       0.0
# 77184                        0.0                       5.0
# 78173                        0.0                       5.0
# 91425                        0.0                       5.0
# 94810                        0.0                       5.0
# 96203                        0.0                       0.0
# 115304                       0.0                       0.0
# 123566                       0.0                       5.0
# 135193                       2.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6263e9d2fd2ee90bb8a2d0b6  6263e9f2fd2ee90bb8a2d0bb  \
# tmdb
# 65931                        0.0                       0.0
# 68267                        0.0                       4.0
# 74440                        0.0                       5.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       5.0
# 94810                        0.0                       0.0
# 96203                        0.0                       5.0
# 115304                       0.0                       0.0
# 123566                       0.0                       4.0
# 135193                       0.0                       3.0
# 154490                       3.0                       0.0
#
# _id     6263ea19fd2ee90bb8a2d0bf  6263ea32fd2ee90bb8a2d0c3  \
# tmdb
# 65931                        0.0                       2.0
# 68267                        0.0                       0.0
# 74440                        0.0                       0.0
# 77184                        0.0                       0.0
# 78173                        0.0                       0.0
# 91425                        0.0                       0.0
# 94810                        0.0                       0.0
# 96203                        3.0                       3.0
# 115304                       0.0                       0.0
# 123566                       0.0                       0.0
# 135193                       0.0                       0.0
# 154490                       0.0                       0.0
#
# _id     6263ea3efd2ee90bb8a2d0c7
# tmdb
# 65931                        0.0
# 68267                        3.0
# 74440                        0.0
# 77184                        2.0
# 78173                        3.0
# 91425                        3.0
# 94810                        0.0
# 96203                        0.0
# 115304                       0.0
# 123566                       3.0
# 135193                       0.0
# 154490                       0.0

# %%
knn_users.iloc[query_index,:].values.reshape(1,-1)
# Out:
# array([[5., 0., 0., 0., 0., 4., 0.]])

# %%
knn_users.reset_index()[knn_users.reset_index()["tmdb"] == 719088]
# Out:
# _id    tmdb  625495df8ca5e225e5473995  625499768ca5e225e5475a58  \
# 90   719088                       3.0                       0.0
#
# _id  6254b1e98ca5e225e548c632  6254b3e18ca5e225e548ce58  \
# 90                        0.0                       0.0
#
# _id  6254c08d8ca5e225e5494015  62556c3b8ca5e225e549587e  \
# 90                        0.0                       2.0
#
# _id  62582dc212014fc3392d66a1
# 90                        0.0

# %%
s = movies.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'genre'
genre_movies = movies.drop('genres', axis=1).join(s)

df = genre_movies
vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = df[df['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()
m = vote_counts.quantile(0.85)

qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title','tmdb', 'year', 'vote_count', 'genre' , 'vote_average', 'popularity']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')

qualified['wr'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) + (m/(m+x['vote_count']) * C), axis=1)
qualified = qualified.sort_values('wr', ascending=False)
qualified = qualified

# %%
qualified.groupby(by="genre").sum("vote_average").sort_values(by=['vote_average'],ascending=False)
# Out:
#                       tmdb  vote_count  vote_average  popularity          wr
# genre
# Drama            118818178        1644           344   31205.530  302.750176
# Comedy           113532636         780           306   51948.972  254.051715
# Animation         78484872         812           194   40159.238  176.619513
# Crime             63263552        1582           194   31937.386  178.304616
# Family            62187876         584           166   36267.788  146.636988
# Romance           39926331         383           120    7177.831  102.351083
# Action            37679810         793           109   15763.500   99.167990
# Thriller          34697353         738            90   14918.536   83.260458
# Fantasy           26615362         315            75   17253.867   67.690851
# Adventure         23272207         236            66    9567.067   59.284420
# TV Movie           8540326         118            28    1486.227   25.527312
# History            7389627         107            28    1991.533   25.049413
# Music              9146931         106            24    2268.742   22.168302
# Mystery           11872526         198            20    5254.410   19.797227
# Science Fiction    5557523          35            15    1264.416   11.917702
# Horror             7941613          52            14    1893.308   12.391560
# War                1931026          15             5     320.721    4.135138

# %%
import mongodb as md

# %%
md.read_mongo("finalyearproject","movies","online")
# Out:
#                            _id    tmdb                          title  \
# 0     624d882287b246f81c48c8b1     278       The Shawshank Redemption
# 1     624d882287b246f81c48c8b3   19404    Dilwale Dulhania Le Jayenge
# 2     624d882287b246f81c48c8b5     238                  The Godfather
# 3     624d882287b246f81c48c8b7  652837  Josee, the Tiger and the Fish
# 4     624d882287b246f81c48c8cf  533514   Violet Evergarden: The Movie
# ...                        ...     ...                            ...
# 1464  624d88d361dd768818c97646   16996                       17 Again
# 1465  624d88d361dd768818c9763a  141052                 Justice League
# 1466  624d88d361dd768818c9763e  102899                        Ant-Man
# 1467  624d88d361dd768818c97644   44912                  Green Lantern
# 1468  624d88d361dd768818c9763c  433945                    Tokyo Ghoul
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     With dreams of diving abroad, Tsuneo gets a jo...
# 4     As the world moves on from the war and technol...
# ...                                                 ...
# 1464  On the brink of a midlife crisis, 30-something...
# 1465  Fuelled by his restored faith in humanity and ...
# 1466  Armed with the astonishing ability to shrink i...
# 1467  For centuries, a small but powerful force of w...
# 1468  A Tokyo college student is attacked by a ghoul...
#
#                                                  genres  vote_count  \
# 0                          [Crime, Drama, Crime, Drama]           0
# 1               [Comedy, Drama, Romance, Drama, Comedy]           0
# 2                          [Crime, Drama, Crime, Drama]           0
# 3         [Animation, Drama, Romance, Animation, Drama]           6
# 4     [Animation, Fantasy, Drama, Romance, Animation...           9
# ...                                                 ...         ...
# 1464                                   [Comedy, Comedy]           0
# 1465      [Action, Adventure, Fantasy, Science Fiction]           0
# 1466               [Action, Adventure, Science Fiction]           0
# 1467     [Action, Adventure, Thriller, Science Fiction]           0
# 1468           [Action, Horror, Drama, Thriller, Drama]           0
#
#       vote_average  popularity release_date
# 0         0.000000      78.147   1994-09-23
# 1         0.000000      29.896   1995-10-20
# 2         0.000000      91.215   1972-03-14
# 3         2.500000      30.509   2020-12-25
# 4         1.555556      42.120   2020-09-18
# ...            ...         ...          ...
# 1464      0.000000      91.448   2009-03-11
# 1465      0.000000      80.543   2017-11-15
# 1466      0.000000      86.827   2015-07-14
# 1467      0.000000      86.645   2011-06-16
# 1468      0.000000      82.517   2017-07-16
#
# [1469 rows x 9 columns]
